# %%
# !python gen_diff.py 'light' 1.0 0.5 0.01 100 100 0.5
# Out:
# /usr/local/lib/python2.7/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ...
# 170385408/170498071 [============================>.] - ETA: 0s2024-10-26 17:22:18.003612: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2024-10-26 17:22:18.003789: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# Model1 loaded
# Initializing resnet50 model
# ...
# 101531648/102853048 [============================>.] - ETA: 0sLoading previously trained weights...
# ...
