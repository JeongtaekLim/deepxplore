# %% [markdown]
# 모델 출처:
# https://www.kaggle.com/code/mostafasamerdorrah/cifar-10-using-resnet50-0-83050#Facts-about-the-data-%F0%9F%92%A1

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.datasets import cifar10


(x_train, Y_train), (x_test, Y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from http://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 169918464/170498071 [============================>.] - ETA: 0s

# %%
import tensorflow as tf
from keras_preprocessing import image
from keras.utils import to_categorical

batch_size = 10

y_train, y_test = Y_train.flatten(), Y_test.flatten()

data_generator = image.ImageDataGenerator(
    samplewise_std_normalization=True,
    validation_split=0.2
)


train_generator = data_generator.flow(
    x_train,
    to_categorical(y_train, num_classes=10),
    batch_size=batch_size,
)

val_generator = data_generator.flow(
    x_train,
    to_categorical(y_train, num_classes=10),
    batch_size=batch_size,
)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(30):
    plt.subplot(6,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i])
    plt.xlabel(class_names[Y_train[i][0]])
plt.show()

# %%
from keras import layers
data_augmentation = tf.keras.Sequential([
  layers.RandomFlip('horizontal'),
  layers.RandomRotation(0.2),
  layers.RandomZoom((-0.2, 0.2)),
  layers.RandomContrast(0.8, 1.2),
  layers.RandomBrightness(0.1),])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-56737fb60de5> in <module>()
#       1 from keras import layers
# ----> 2 data_augmentation = tf.keras.Sequential([
#       3   layers.RandomFlip('horizontal'),
#       4   layers.RandomRotation(0.2),
#       5   layers.RandomZoom((-0.2, 0.2)),
#
# AttributeError: 'module' object has no attribute 'keras'
